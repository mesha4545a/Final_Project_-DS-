# %% [markdown]
# ### import the Dataset

# %%
# import pandas library
import pandas as pd
# the dataset
df = pd.read_csv("D:\Final_project\data\Owid-covid-data-prepared.csv")
# show me the last 5 rows 
df.tail()
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 65041      ZWE    Africa  Zimbabwe  2021-02-07      34552.0       65.0
# 65042      ZWE    Africa  Zimbabwe  2021-02-08      34658.0      106.0
# 65043      ZWE    Africa  Zimbabwe  2021-02-09      34781.0      123.0
# 65044      ZWE    Africa  Zimbabwe  2021-02-10      34864.0       83.0
# 65045      ZWE    Africa  Zimbabwe  2021-02-11      34864.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 65041             166.286        1326.0        10.0               15.571  ...
# 65042             158.571        1339.0        13.0               15.000  ...
# 65043             138.143        1353.0        14.0               14.143  ...
# 65044             128.571        1364.0        11.0               13.571  ...
# 65045              99.000        1364.0         0.0               10.857  ...
#
# ...

# %% [markdown]
# ### Prepare the Dataset for Modeling

# %%
# separate the data based on location
h = df.location.unique() # list of the locations
for i in range(len(h)): # go thro the list 
    y = df.loc[df['location'] == '%s' %h[i]] # spearate base on location 
    y = y.filter(['date','new_cases'])# remove all columns except "date" and "new cases"
    y.columns = ['ds', 'y'] # rename the columns 
    globals()['%s' %h[i]] =  y # give every location it own dataset

# %%
h = df.location.unique()
print(len(h))
# Out:
# 191

# %%
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
 
def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')
 
series = [i for i in df.location]
# Create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
print(dataframe.head(5))
 
# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
 
# persistence model
def model_persistence(x):
	return x
 
# walk-forward validation
predictions = list()
for x in test_X:
	yhat = model_persistence(x)
	predictions.append(yhat)
test_score = mean_squared_error(test_y, predictions)
print('Test MSE: %.3f' % test_score)
 
# plot predictions and expected results
pyplot.plot(train_y)
pyplot.plot([None for i in train_y] + [x for x in test_y])
pyplot.plot([None for i in train_y] + [x for x in predictions])
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-901cf539b940> in <module>
#       7 series = [i for i in df.location]
#       8 # Create lagged dataset
# ----> 9 values = DataFrame(series.values)
#      10 dataframe = concat([values.shift(1), values], axis=1)
#      11 dataframe.columns = ['t-1', 't+1']
#
# NameError: name 'DataFrame' is not defined
